# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

# If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print("-----------------------------")

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
    
        try:
            if city_weather["weather"][0]["main"]=="Rain":
                city_rain_inches= city_weather["rain"]["3h"]
            else: 
                city_rain_inches=0
        except:  print (f"City not found. Skipping...")
             
        try:
            if city_weather["weather"][0]["main"]=="Snow":
                city_snow_inches= city_weather["snow"]["3h"]
            else: 
                 city_snow_inches=0
        except:  print (f"City not found. Skipping...")
        
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print("-----------------------------")
print('Data Retrieval Complete')
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | eureka
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | preobrazheniye
# Processing Record 5 of Set 1 | sayville
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 1 | kaeo
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | ixtapa
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | batagay
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | dabat
# Processing Record 20 of Set 1 | boca do acre
# Processing Record 21 of Set 1 | beyneu
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | shingu
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | rocha
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | ngunguru
# Processing Record 29 of Set 1 | denpasar
# Processing Record 30 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 31 of Set 1 | pochutla
# Processing Record 32 of Set 1 | warrnambool
# Processing Record 33 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | matara
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | salalah
# Processing Record 45 of Set 1 | quelimane
# Processing Record 46 of Set 1 | port lincoln
# Processing Record 47 of Set 1 | katsuura
# Processing Record 48 of Set 1 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 49 of Set 1 | sayansk
# Processing Record 50 of Set 1 | kapoeta
# Processing Record 1 of Set 2 | amazar
# Processing Record 2 of Set 2 | victoria
# City not found. Skipping...
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | khani
# Processing Record 6 of Set 2 | fairbanks
# City not found. Skipping...
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | westport
# Processing Record 10 of Set 2 | elizabeth city
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | half moon bay
# Processing Record 14 of Set 2 | nador
# Processing Record 15 of Set 2 | litovko
# Processing Record 16 of Set 2 | hastings
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | bulgan
# Processing Record 22 of Set 2 | kavieng
# City not found. Skipping...
# Processing Record 23 of Set 2 | hengyang
# Processing Record 24 of Set 2 | miyako
# City not found. Skipping...
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | mattawa
# Processing Record 27 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 2 | egvekinot
# Processing Record 29 of Set 2 | tuyen quang
# Processing Record 30 of Set 2 | santiago
# Processing Record 31 of Set 2 | beloha
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | black river
# Processing Record 34 of Set 2 | port moresby
# City not found. Skipping...
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | erdenet
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | mwinilunga
# City not found. Skipping...
# Processing Record 40 of Set 2 | litoral del san juan
# City not found. Skipping...
# Processing Record 41 of Set 2 | medicine hat
# Processing Record 42 of Set 2 | oranjemund
# Processing Record 43 of Set 2 | chimbote
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | talcahuano
# Processing Record 46 of Set 2 | grafton
# Processing Record 47 of Set 2 | aqtobe
# Processing Record 48 of Set 2 | lokosovo
# Processing Record 49 of Set 2 | gidole
# Processing Record 50 of Set 2 | caravelas
# Processing Record 1 of Set 3 | harwich
# Processing Record 2 of Set 3 | adrar
# Processing Record 3 of Set 3 | bryansk
# Processing Record 4 of Set 3 | oranjestad
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 3 | lanxi
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | pangody
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | clyde river
# Processing Record 12 of Set 3 | belaya gora
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | beian
# Processing Record 15 of Set 3 | kieta
# City not found. Skipping...
# Processing Record 16 of Set 3 | bandarbeyla
# Processing Record 17 of Set 3 | bredasdorp
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | barrow
# Processing Record 23 of Set 3 | maragogi
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | ilulissat
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | fort frances
# Processing Record 28 of Set 3 | beringovskiy
# Processing Record 29 of Set 3 | vila do maio
# Processing Record 30 of Set 3 | novichikha
# Processing Record 31 of Set 3 | tabas
# Processing Record 32 of Set 3 | eskisehir
# Processing Record 33 of Set 3 | paamiut
# Processing Record 34 of Set 3 | evensk
# Processing Record 35 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 36 of Set 3 | buala
# Processing Record 37 of Set 3 | pangai
# Processing Record 38 of Set 3 | emba
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | glasgow
# City not found. Skipping...
# Processing Record 41 of Set 3 | mezen
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | varkkallai
# Processing Record 45 of Set 3 | berlevag
# Processing Record 46 of Set 3 | rock springs
# Processing Record 47 of Set 3 | chunian
# Processing Record 48 of Set 3 | boden
# City not found. Skipping...
# Processing Record 49 of Set 3 | bonavista
# Processing Record 50 of Set 3 | prince rupert
# City not found. Skipping...
# Processing Record 1 of Set 4 | rapid city
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | matagami
# City not found. Skipping...
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 6 of Set 4 | cayenne
# City not found. Skipping...
# Processing Record 7 of Set 4 | burnie
# Processing Record 8 of Set 4 | lakes entrance
# City not found. Skipping...
# Processing Record 9 of Set 4 | hisua
# Processing Record 10 of Set 4 | havre-saint-pierre
# Processing Record 11 of Set 4 | kyra
# City not found. Skipping...
# Processing Record 12 of Set 4 | yomitan
# City not found. Skipping...
# Processing Record 13 of Set 4 | alice springs
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 16 of Set 4 | leh
# Processing Record 17 of Set 4 | santana do matos
# Processing Record 18 of Set 4 | atuona
# City not found. Skipping...
# Processing Record 19 of Set 4 | bay roberts
# Processing Record 20 of Set 4 | portobelo
# Processing Record 21 of Set 4 | kawalu
# Processing Record 22 of Set 4 | aykhal
# Processing Record 23 of Set 4 | hingorja
# Processing Record 24 of Set 4 | constitucion
# Processing Record 25 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | kaolack
# Processing Record 29 of Set 4 | danielskuil
# Processing Record 30 of Set 4 | sujiatun
# Processing Record 31 of Set 4 | lubaczow
# Processing Record 32 of Set 4 | dhule
# Processing Record 33 of Set 4 | mwene-ditu
# Processing Record 34 of Set 4 | buritis
# Processing Record 35 of Set 4 | totness
# Processing Record 36 of Set 4 | bolivar
# Processing Record 37 of Set 4 | semey
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | whitianga
# Processing Record 40 of Set 4 | sterling
# Processing Record 41 of Set 4 | dikson
# Processing Record 42 of Set 4 | mar del plata
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | castro
# City not found. Skipping...
# Processing Record 45 of Set 4 | nome
# Processing Record 46 of Set 4 | kungurtug
# Processing Record 47 of Set 4 | hervey bay
# Processing Record 48 of Set 4 | bani walid
# Processing Record 49 of Set 4 | omsukchan
# Processing Record 50 of Set 4 | port blair
# Processing Record 1 of Set 5 | george
# Processing Record 2 of Set 5 | liaqatabad
# Processing Record 3 of Set 5 | broome
# Processing Record 4 of Set 5 | pangnirtung
# Processing Record 5 of Set 5 | manokwari
# Processing Record 6 of Set 5 | havoysund
# City not found. Skipping...
# Processing Record 7 of Set 5 | roald
# Processing Record 8 of Set 5 | jalu
# Processing Record 9 of Set 5 | talara
# Processing Record 10 of Set 5 | mount isa
# Processing Record 11 of Set 5 | ruteng
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | pareora
# Processing Record 16 of Set 5 | husavik
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | shonguy
# Processing Record 19 of Set 5 | cabo san lucas
# Processing Record 20 of Set 5 | tasiilaq
# City not found. Skipping...
# Processing Record 21 of Set 5 | coquimbo
# Processing Record 22 of Set 5 | bara
# Processing Record 23 of Set 5 | almeirim
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | sekoma
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | rawson
# Processing Record 29 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 5 | ambon
# Processing Record 31 of Set 5 | diffa
# Processing Record 32 of Set 5 | ajaccio
# Processing Record 33 of Set 5 | anadyr
# Processing Record 34 of Set 5 | dunedin
# Processing Record 35 of Set 5 | williston
# Processing Record 36 of Set 5 | atherton
# City not found. Skipping...
# Processing Record 37 of Set 5 | amapa
# Processing Record 38 of Set 5 | praya
# Processing Record 39 of Set 5 | haines junction
# Processing Record 40 of Set 5 | butaritari
# City not found. Skipping...
# Processing Record 41 of Set 5 | moree
# Processing Record 42 of Set 5 | san carlos del zulia
# Processing Record 43 of Set 5 | hamilton
# Processing Record 44 of Set 5 | bouna
# Processing Record 45 of Set 5 | salamanca
# Processing Record 46 of Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | cockburn town
# Processing Record 49 of Set 5 | aksha
# Processing Record 50 of Set 5 | malinovoye ozero
# Processing Record 1 of Set 6 | faanui
# City not found. Skipping...
# Processing Record 2 of Set 6 | iqaluit
# Processing Record 3 of Set 6 | le vauclin
# Processing Record 4 of Set 6 | lenzing
# Processing Record 5 of Set 6 | lavrentiya
# Processing Record 6 of Set 6 | vardo
# Processing Record 7 of Set 6 | honiara
# Processing Record 8 of Set 6 | ponta do sol
# Processing Record 9 of Set 6 | labuhan
# Processing Record 10 of Set 6 | gamba
# Processing Record 11 of Set 6 | tuatapere
# Processing Record 12 of Set 6 | ust-omchug
# Processing Record 13 of Set 6 | roebourne
# Processing Record 14 of Set 6 | okato
# Processing Record 15 of Set 6 | inverell
# Processing Record 16 of Set 6 | palmer
# Processing Record 17 of Set 6 | provideniya
# Processing Record 18 of Set 6 | nueva guinea
# Processing Record 19 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 6 | russell
# Processing Record 21 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 6 | itajobi
# Processing Record 23 of Set 6 | misantla
# Processing Record 24 of Set 6 | mudon
# Processing Record 25 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 6 | great falls
# City not found. Skipping...
# Processing Record 27 of Set 6 | wanning
# Processing Record 28 of Set 6 | tadine
# Processing Record 29 of Set 6 | zhezkazgan
# Processing Record 30 of Set 6 | salisbury
# Processing Record 31 of Set 6 | severo-kurilsk
# Processing Record 32 of Set 6 | east london
# City not found. Skipping...
# Processing Record 33 of Set 6 | meulaboh
# Processing Record 34 of Set 6 | zhigansk
# Processing Record 35 of Set 6 | kama
# Processing Record 36 of Set 6 | samarai
# Processing Record 37 of Set 6 | vanderhoof
# Processing Record 38 of Set 6 | la ronge
# Processing Record 39 of Set 6 | koumra
# Processing Record 40 of Set 6 | letlhakane
# Processing Record 41 of Set 6 | quatre cocos
# Processing Record 42 of Set 6 | nantucket
# Processing Record 43 of Set 6 | zaraza
# Processing Record 44 of Set 6 | karratha
# Processing Record 45 of Set 6 | along
# Processing Record 46 of Set 6 | kozulka
# Processing Record 47 of Set 6 | saint george
# Processing Record 48 of Set 6 | khandagayty
# Processing Record 49 of Set 6 | lewistown
# Processing Record 50 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 7 | flinders
# Processing Record 2 of Set 7 | olafsvik
# City not found. Skipping...
# Processing Record 3 of Set 7 | bubaque
# Processing Record 4 of Set 7 | kampene
# Processing Record 5 of Set 7 | moose factory
# City not found. Skipping...
# Processing Record 6 of Set 7 | athabasca
# Processing Record 7 of Set 7 | constantine
# Processing Record 8 of Set 7 | aktash
# Processing Record 9 of Set 7 | gat
# Processing Record 10 of Set 7 | ucluelet
# Processing Record 11 of Set 7 | chippewa falls
# Processing Record 12 of Set 7 | aldama
# Processing Record 13 of Set 7 | lar
# Processing Record 14 of Set 7 | kangaatsiaq
# Processing Record 15 of Set 7 | esna
# Processing Record 16 of Set 7 | kloulklubed
# City not found. Skipping...
# Processing Record 17 of Set 7 | souillac
# Processing Record 18 of Set 7 | gostinari
# Processing Record 19 of Set 7 | iskateley
# Processing Record 20 of Set 7 | komsomolskiy
# Processing Record 21 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 7 | tavda
# Processing Record 23 of Set 7 | jasper
# Processing Record 24 of Set 7 | saint-pierre
# Processing Record 25 of Set 7 | sainte-claire
# Processing Record 26 of Set 7 | south venice
# Processing Record 27 of Set 7 | meadow lake
# Processing Record 28 of Set 7 | menongue
# City not found. Skipping...
# Processing Record 29 of Set 7 | beira
# Processing Record 30 of Set 7 | vung tau
# Processing Record 31 of Set 7 | diamantino
# Processing Record 32 of Set 7 | caceres
# Processing Record 33 of Set 7 | torit
# Processing Record 34 of Set 7 | zheleznodorozhnyy
# Processing Record 35 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 7 | toktogul
# Processing Record 37 of Set 7 | garissa
# Processing Record 38 of Set 7 | riyadh
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | rio verde de mato grosso
# Processing Record 41 of Set 7 | fano
# Processing Record 42 of Set 7 | henties bay
# City not found. Skipping...
# Processing Record 43 of Set 7 | fenoarivo
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | pravda
# Processing Record 46 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 7 | kaitangata
# Processing Record 48 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 49 of Set 7 | rio gallegos
# Processing Record 50 of Set 7 | czluchow
# Processing Record 1 of Set 8 | malatya
# Processing Record 2 of Set 8 | plouzane
# Processing Record 3 of Set 8 | sibolga
# Processing Record 4 of Set 8 | mabamba
# City not found. Skipping...
# Processing Record 5 of Set 8 | calabozo
# Processing Record 6 of Set 8 | faya
# Processing Record 7 of Set 8 | sorong
# Processing Record 8 of Set 8 | ugoofaaru
# Processing Record 9 of Set 8 | colibasi
# Processing Record 10 of Set 8 | steenwijk
# Processing Record 11 of Set 8 | buribay
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | rio grande
# Processing Record 14 of Set 8 | lazaro cardenas
# Processing Record 15 of Set 8 | fuling
# Processing Record 16 of Set 8 | edd
# Processing Record 17 of Set 8 | galveston
# Processing Record 18 of Set 8 | tiksi
# Processing Record 19 of Set 8 | kochevo
# Processing Record 20 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 8 | seoul
# Processing Record 22 of Set 8 | gerash
# Processing Record 23 of Set 8 | aklavik
# Processing Record 24 of Set 8 | axim
# Processing Record 25 of Set 8 | yar-sale
# Processing Record 26 of Set 8 | mandalgovi
# Processing Record 27 of Set 8 | yablonovo
# City not found. Skipping...
# Processing Record 28 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 8 | tiznit
# Processing Record 30 of Set 8 | luis correia
# Processing Record 31 of Set 8 | norman wells
# Processing Record 32 of Set 8 | huarmey
# Processing Record 33 of Set 8 | ola
# Processing Record 34 of Set 8 | zambezi
# City not found. Skipping...
# Processing Record 35 of Set 8 | mitu
# City not found. Skipping...
# Processing Record 36 of Set 8 | ouesso
# Processing Record 37 of Set 8 | wattegama
# Processing Record 38 of Set 8 | cotacachi
# City not found. Skipping...
# Processing Record 39 of Set 8 | saint pete beach
# Processing Record 40 of Set 8 | sur
# Processing Record 41 of Set 8 | babusnica
# Processing Record 42 of Set 8 | grindavik
# City not found. Skipping...
# Processing Record 43 of Set 8 | alpena
# Processing Record 44 of Set 8 | juneau
# City not found. Skipping...
# Processing Record 45 of Set 8 | illintsi
# Processing Record 46 of Set 8 | rae bareli
# Processing Record 47 of Set 8 | guerrero negro
# Processing Record 48 of Set 8 | awbari
# Processing Record 49 of Set 8 | tomigusuku
# Processing Record 50 of Set 8 | praia da vitoria
# Processing Record 1 of Set 9 | ust-uda
# Processing Record 2 of Set 9 | lala
# Processing Record 3 of Set 9 | svetlyy
# Processing Record 4 of Set 9 | korla
# Processing Record 5 of Set 9 | garowe
# Processing Record 6 of Set 9 | hobyo
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | luderitz
# Processing Record 9 of Set 9 | ancud
# Processing Record 10 of Set 9 | maniitsoq
# Processing Record 11 of Set 9 | puerto ayacucho
# Processing Record 12 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 13 of Set 9 | mae ramat
# Processing Record 14 of Set 9 | vanimo
# Processing Record 15 of Set 9 | waipawa
# Processing Record 16 of Set 9 | larsnes
# Processing Record 17 of Set 9 | san carlos de bariloche
# Processing Record 18 of Set 9 | batemans bay
# Processing Record 19 of Set 9 | cap malheureux
# Processing Record 20 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 21 of Set 9 | pedernales
# Processing Record 22 of Set 9 | kunming
# Processing Record 23 of Set 9 | hongjiang
# Processing Record 24 of Set 9 | ornskoldsvik
# City not found. Skipping...
# Processing Record 25 of Set 9 | scarborough
# Processing Record 26 of Set 9 | trier
# Processing Record 27 of Set 9 | goderich
# Processing Record 28 of Set 9 | kalabo
# Processing Record 29 of Set 9 | shambu
# Processing Record 30 of Set 9 | udachnyy
# Processing Record 31 of Set 9 | nagato
# Processing Record 32 of Set 9 | fort nelson
# Processing Record 33 of Set 9 | nemuro
# Processing Record 34 of Set 9 | whitehorse
# Processing Record 35 of Set 9 | superior
# Processing Record 36 of Set 9 | comodoro rivadavia
# Processing Record 37 of Set 9 | margate
# Processing Record 38 of Set 9 | belaya
# Processing Record 39 of Set 9 | iracoubo
# Processing Record 40 of Set 9 | cheyenne
# City not found. Skipping...
# Processing Record 41 of Set 9 | skelleftea
# Processing Record 42 of Set 9 | necochea
# City not found. Skipping...
# Processing Record 43 of Set 9 | wageningen
# Processing Record 44 of Set 9 | balkhash
# Processing Record 45 of Set 9 | sao joao da barra
# Processing Record 46 of Set 9 | port-gentil
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | ostersund
# Processing Record 49 of Set 9 | bairiki
# Processing Record 50 of Set 9 | huoqiu
# Processing Record 1 of Set 10 | sabha
# Processing Record 2 of Set 10 | andahuaylas
# City not found. Skipping...
# Processing Record 3 of Set 10 | arnhem
# Processing Record 4 of Set 10 | kekri
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | thinadhoo
# Processing Record 7 of Set 10 | naze
# Processing Record 8 of Set 10 | aguimes
# Processing Record 9 of Set 10 | lena
# Processing Record 10 of Set 10 | lebu
# Processing Record 11 of Set 10 | rogun
# City not found. Skipping...
# Processing Record 12 of Set 10 | charters towers
# Processing Record 13 of Set 10 | chitral
# Processing Record 14 of Set 10 | adre
# Processing Record 15 of Set 10 | perbaungan
# Processing Record 16 of Set 10 | grand gaube
# Processing Record 17 of Set 10 | lalibela
# Processing Record 18 of Set 10 | biltine
# Processing Record 19 of Set 10 | paramonga
# Processing Record 20 of Set 10 | lourdes
# Processing Record 21 of Set 10 | tazmalt
# Processing Record 22 of Set 10 | bilibino
# Processing Record 23 of Set 10 | verkhneuralsk
# Processing Record 24 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 25 of Set 10 | topolobampo
# Processing Record 26 of Set 10 | bonfim
# Processing Record 27 of Set 10 | reitz
# Processing Record 28 of Set 10 | san quintin
# Processing Record 29 of Set 10 | caucaia
# Processing Record 30 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 10 | churapcha
# Processing Record 32 of Set 10 | sangar
# Processing Record 33 of Set 10 | da lat
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | antofagasta
# Processing Record 36 of Set 10 | dalbandin
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 39 of Set 10 | guipavas
# Processing Record 40 of Set 10 | tucurui
# City not found. Skipping...
# Processing Record 41 of Set 10 | mala
# City not found. Skipping...
# Processing Record 42 of Set 10 | ambovombe
# Processing Record 43 of Set 10 | olga
# Processing Record 44 of Set 10 | bonita springs
# Processing Record 45 of Set 10 | badiraguato
# Processing Record 46 of Set 10 | moissala
# Processing Record 47 of Set 10 | plettenberg bay
# Processing Record 48 of Set 10 | raudeberg
# Processing Record 49 of Set 10 | pangoa
# Processing Record 50 of Set 10 | cidreira
# Processing Record 1 of Set 11 | puerto escondido
# Processing Record 2 of Set 11 | nabire
# City not found. Skipping...
# Processing Record 3 of Set 11 | aasiaat
# Processing Record 4 of Set 11 | redlands
# Processing Record 5 of Set 11 | bo
# City not found. Skipping...
# Processing Record 6 of Set 11 | talagang
# Processing Record 7 of Set 11 | auki
# Processing Record 8 of Set 11 | tommot
# Processing Record 9 of Set 11 | ust-maya
# Processing Record 10 of Set 11 | strezhevoy
# Processing Record 11 of Set 11 | vary
# Processing Record 12 of Set 11 | angoche
# Processing Record 13 of Set 11 | trinidad
# Processing Record 14 of Set 11 | sakaraha
# Processing Record 15 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 11 | airai
# Processing Record 17 of Set 11 | verkhoyansk
# Processing Record 18 of Set 11 | tingo maria
# Processing Record 19 of Set 11 | port hardy
# Processing Record 20 of Set 11 | jiblah
# Processing Record 21 of Set 11 | ulladulla
# Processing Record 22 of Set 11 | harper
# Processing Record 23 of Set 11 | altagracia de orituco
# Processing Record 24 of Set 11 | valenca
# Processing Record 25 of Set 11 | boa vista
# Processing Record 26 of Set 11 | fleetwood
# Processing Record 27 of Set 11 | namatanai
# City not found. Skipping...
# Processing Record 28 of Set 11 | tautira
# City not found. Skipping...
# Processing Record 29 of Set 11 | shimoda
# Processing Record 30 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 11 | sinnamary
# Processing Record 32 of Set 11 | qinzhou
# Processing Record 33 of Set 11 | mackay
# City not found. Skipping...
# Processing Record 34 of Set 11 | umarkot
# Processing Record 35 of Set 11 | derzhavinsk
# Processing Record 36 of Set 11 | nuuk
# Processing Record 37 of Set 11 | bonthe
# Processing Record 38 of Set 11 | hays
# Processing Record 39 of Set 11 | angra
# City not found. Skipping...
# Processing Record 40 of Set 11 | sitka
# City not found. Skipping...
# Processing Record 41 of Set 11 | kolokani
# Processing Record 42 of Set 11 | joshimath
# Processing Record 43 of Set 11 | vitre
# Processing Record 44 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 11 | skreia
# Processing Record 46 of Set 11 | issenye
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | we
# City not found. Skipping...
# Processing Record 49 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 50 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 12 | granja
# Processing Record 2 of Set 12 | ormara
# Processing Record 3 of Set 12 | lafiagi
# Processing Record 4 of Set 12 | tessalit
# Processing Record 5 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 6 of Set 12 | miraflores
# Processing Record 7 of Set 12 | brejo santo
# Processing Record 8 of Set 12 | haileybury
# City not found. Skipping...
# Processing Record 9 of Set 12 | takoradi
# Processing Record 10 of Set 12 | svetlaya
# Processing Record 11 of Set 12 | kupang
# Processing Record 12 of Set 12 | natal
# Processing Record 13 of Set 12 | usinsk
# City not found. Skipping...
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | dolores
# Processing Record 16 of Set 12 | betul
# Processing Record 17 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 12 | touros
# Processing Record 19 of Set 12 | saquarema
# Processing Record 20 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 12 | turukhansk
# Processing Record 22 of Set 12 | rafraf
# Processing Record 23 of Set 12 | rommerskirchen
# Processing Record 24 of Set 12 | abalak
# Processing Record 25 of Set 12 | manta
# Processing Record 26 of Set 12 | aguadilla
# Processing Record 27 of Set 12 | kamina
# Processing Record 28 of Set 12 | belen
# Processing Record 29 of Set 12 | shitkino
# Processing Record 30 of Set 12 | walvis bay
# Processing Record 31 of Set 12 | moroto
# Processing Record 32 of Set 12 | sioux lookout
# Processing Record 33 of Set 12 | coihaique
# Processing Record 34 of Set 12 | huanren
# Processing Record 35 of Set 12 | khor
# Processing Record 36 of Set 12 | batagay-alyta
# Processing Record 37 of Set 12 | pisco
# Processing Record 38 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 12 | brae
# Processing Record 40 of Set 12 | hami
# City not found. Skipping...
# Processing Record 41 of Set 12 | steamboat springs
# Processing Record 42 of Set 12 | dondukovskaya
# Processing Record 43 of Set 12 | plaster rock
# Processing Record 44 of Set 12 | uige
# City not found. Skipping...
# Processing Record 45 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 12 | moengo
# Processing Record 47 of Set 12 | aranos
# Processing Record 48 of Set 12 | biak
# Processing Record 49 of Set 12 | durres
# Processing Record 50 of Set 12 | ecoporanga
# Processing Record 1 of Set 13 | port augusta
# Processing Record 2 of Set 13 | turbat
# Processing Record 3 of Set 13 | linguere
# Processing Record 4 of Set 13 | baturaja
# City not found. Skipping...
# Processing Record 5 of Set 13 | micheweni
# Processing Record 6 of Set 13 | kristianstad
# Processing Record 7 of Set 13 | botou
# Processing Record 8 of Set 13 | danciulesti
# Processing Record 9 of Set 13 | camocim
# Processing Record 10 of Set 13 | carballo
# Processing Record 11 of Set 13 | markova
# Processing Record 12 of Set 13 | michigan city
# Processing Record 13 of Set 13 | boende
# Processing Record 14 of Set 13 | lander
# City not found. Skipping...
# Processing Record 15 of Set 13 | honggang
# Processing Record 16 of Set 13 | solak
# Processing Record 17 of Set 13 | klaksvik
# Processing Record 18 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 13 | taoudenni
# Processing Record 20 of Set 13 | quebec
# Processing Record 21 of Set 13 | araguaina
# Processing Record 22 of Set 13 | sabana de torres
# Processing Record 23 of Set 13 | zhanaozen
# Processing Record 24 of Set 13 | te anau
# Processing Record 25 of Set 13 | kirakira
# Processing Record 26 of Set 13 | maryville
# Processing Record 27 of Set 13 | maldonado
# Processing Record 28 of Set 13 | tsentralnyy
# City not found. Skipping...
# Processing Record 29 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 13 | ewa beach
# Processing Record 31 of Set 13 | sisimiut
# Processing Record 32 of Set 13 | ca mau
# Processing Record 33 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 13 | winchester
# Processing Record 35 of Set 13 | college
# Processing Record 36 of Set 13 | itoman
# Processing Record 37 of Set 13 | nouadhibou
# Processing Record 38 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 13 | linqiong
# Processing Record 40 of Set 13 | xichang
# Processing Record 41 of Set 13 | anisoc
# City not found. Skipping...
# Processing Record 42 of Set 13 | madimba
# Processing Record 43 of Set 13 | parnamirim
# Processing Record 44 of Set 13 | colares
# Processing Record 45 of Set 13 | koroni
# Processing Record 46 of Set 13 | anloga
# Processing Record 47 of Set 13 | berdigestyakh
# Processing Record 48 of Set 13 | stranraer
# Processing Record 49 of Set 13 | gornyak
# Processing Record 50 of Set 13 | bowen
# Processing Record 1 of Set 14 | poso
# Processing Record 2 of Set 14 | jabinyanah
# Processing Record 3 of Set 14 | coahuayana
# Processing Record 4 of Set 14 | mount darwin
# Processing Record 5 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 14 | marsabit
# Processing Record 7 of Set 14 | katangli
# City not found. Skipping...
# Processing Record 8 of Set 14 | wilmington
# Processing Record 9 of Set 14 | kojnare
# Processing Record 10 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 14 | mitsamiouli
# Processing Record 12 of Set 14 | yerbogachen
# Processing Record 13 of Set 14 | nyurba
# Processing Record 14 of Set 14 | kudahuvadhoo
# Processing Record 15 of Set 14 | hong gai
# Processing Record 16 of Set 14 | nampula
# Processing Record 17 of Set 14 | wahpeton
# Processing Record 18 of Set 14 | skjervoy
# Processing Record 19 of Set 14 | manono
# Processing Record 20 of Set 14 | sheksna
# Processing Record 21 of Set 14 | chumikan
# Processing Record 22 of Set 14 | nikel
# Processing Record 23 of Set 14 | balabac
# Processing Record 24 of Set 14 | nehe
# Processing Record 25 of Set 14 | trairi
# Processing Record 26 of Set 14 | ransang
# Processing Record 27 of Set 14 | oxford
# Processing Record 28 of Set 14 | mercedes
# Processing Record 29 of Set 14 | carson city
# Processing Record 30 of Set 14 | brigantine
# Processing Record 31 of Set 14 | acapulco
# Processing Record 32 of Set 14 | mporokoso
# City not found. Skipping...
# Processing Record 33 of Set 14 | nalut
# Processing Record 34 of Set 14 | honghu
# Processing Record 35 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 14 | neryungri
# Processing Record 37 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 38 of Set 14 | ramhormoz
# Processing Record 39 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 14 | port lavaca
# Processing Record 41 of Set 14 | kaman
# Processing Record 42 of Set 14 | ust-barguzin
# Processing Record 43 of Set 14 | ciudad bolivar
# Processing Record 44 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 14 | sohag
# Processing Record 46 of Set 14 | kostomuksha
# City not found. Skipping...
# Processing Record 47 of Set 14 | quesnel
# Processing Record 48 of Set 14 | ketchikan
# City not found. Skipping...
# Processing Record 49 of Set 14 | hambantota
# Processing Record 50 of Set 14 | muroto
# Processing Record 1 of Set 15 | sherlovaya gora
# Processing Record 2 of Set 15 | blythe
# Processing Record 3 of Set 15 | ulaangom
# Processing Record 4 of Set 15 | rohnert park
# Processing Record 5 of Set 15 | puerto narino
# City not found. Skipping...
# Processing Record 6 of Set 15 | athol
# Processing Record 7 of Set 15 | tostamaa
# City not found. Skipping...
# Processing Record 8 of Set 15 | paita
# Processing Record 9 of Set 15 | chipata
# City not found. Skipping...
# Processing Record 10 of Set 15 | pouembout
# Processing Record 11 of Set 15 | dragor
# Processing Record 12 of Set 15 | bafoulabe
# Processing Record 13 of Set 15 | mbour
# Processing Record 14 of Set 15 | kaseda
# Processing Record 15 of Set 15 | porto velho
# Processing Record 16 of Set 15 | namtsy
# Processing Record 17 of Set 15 | novaya igirma
# Processing Record 18 of Set 15 | matola
# Processing Record 19 of Set 15 | kavaratti
# Processing Record 20 of Set 15 | kojori
# Processing Record 21 of Set 15 | yeniseysk
# Processing Record 22 of Set 15 | yarada
# Processing Record 23 of Set 15 | banda aceh
# Processing Record 24 of Set 15 | deputatskiy
# Processing Record 25 of Set 15 | gueret
# Processing Record 26 of Set 15 | progreso
# Processing Record 27 of Set 15 | bathsheba
# Processing Record 28 of Set 15 | storsteinnes
# Processing Record 29 of Set 15 | ulaanbaatar
# Processing Record 30 of Set 15 | mangrol
# Processing Record 31 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 15 | raga
# Processing Record 33 of Set 15 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 34 of Set 15 | mehamn
# City not found. Skipping...
# Processing Record 35 of Set 15 | serebryansk
# Processing Record 36 of Set 15 | simbahan
# Processing Record 37 of Set 15 | manjacaze
# Processing Record 38 of Set 15 | nanyang
# City not found. Skipping...
# Processing Record 39 of Set 15 | chiang khong
# Processing Record 40 of Set 15 | oga
# Processing Record 41 of Set 15 | zaysan
# Processing Record 42 of Set 15 | pavlovka
# Processing Record 43 of Set 15 | chebsara
# Processing Record 44 of Set 15 | port macquarie
# Processing Record 45 of Set 15 | nara
# Processing Record 46 of Set 15 | hondo
# Processing Record 47 of Set 15 | ayagoz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  \
# 0            hilo  19.7297 -155.0900     79.39           clear sky
# 1          eureka  40.8021 -124.1637     58.68           clear sky
# 2         rikitea -23.1203 -134.9692     77.85          few clouds
# 3  preobrazheniye  42.9019  133.9064     15.24     overcast clouds
# 4        sayville  40.7359  -73.0821     44.29     overcast clouds
# 5          narsaq  60.9167  -46.0500     -2.22     overcast clouds
# 6        hermanus -34.4187   19.2345     64.90           clear sky
# 7            kaeo -35.1000  173.7833     60.33     overcast clouds
# 8    punta arenas -53.1500  -70.9167     55.51       broken clouds
# 9       cape town -33.9258   18.4232     65.12          few clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0              0              0        65           0        2.44      US
# 1              0              0        74           0       11.01      US
# 2              0              0        72          15       12.10      PF
# 3              0              0        75          98        9.33      RU
# 4              0              0        78         100       11.50      US
# 5              0              0        78          99        3.60      GL
# 6              0              0        70           1       12.68      ZA
# 7              0              0        91          93        3.31      NZ
# 8              0              0        54          75       39.12      CL
# 9              0              0        71          20       24.16      ZA

# %%
# Create the output file (CSV).
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
